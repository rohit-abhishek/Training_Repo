# %% [markdown]
# #### This is 3rd program which will use %timeit command to evaluate the benchmark
# #### OR to run timeit command on command line interface use below command -
#         python -m timeit -s "from particle_simulator import benchmark
#         benchmark()"
# #### OR Use next program particle_timeit.py

# %%
# import benchmark 
from particle_benchmark import benchmark

# %timeit benchmark()
# Out:
# 2.3 s ± 12.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
